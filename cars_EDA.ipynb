# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd


file_path = '/content/drive/MyDrive/vehicles.csv'
df = pd.read_csv(file_path)
print(df.head())
# Out:
#            id                                                url  \
# 0  7222695916  https://prescott.craigslist.org/cto/d/prescott...
# 1  7218891961  https://fayar.craigslist.org/ctd/d/bentonville...
# 2  7221797935  https://keys.craigslist.org/cto/d/summerland-k...
# 3  7222270760  https://worcester.craigslist.org/cto/d/west-br...
# 4  7210384030  https://greensboro.craigslist.org/cto/d/trinit...
#
#                    region                         region_url  price  year  \
# 0                prescott    https://prescott.craigslist.org   6000   NaN
# 1            fayetteville       https://fayar.craigslist.org  11900   NaN
# 2            florida keys        https://keys.craigslist.org  21000   NaN
# 3  worcester / central MA   https://worcester.craigslist.org   1500   NaN
# 4              greensboro  https://greensboro.craigslist.org   4900   NaN
#
#   manufacturer model condition cylinders  ... size  type paint_color  \
# 0          NaN   NaN       NaN       NaN  ...  NaN   NaN         NaN
# 1          NaN   NaN       NaN       NaN  ...  NaN   NaN         NaN
# 2          NaN   NaN       NaN       NaN  ...  NaN   NaN         NaN
# 3          NaN   NaN       NaN       NaN  ...  NaN   NaN         NaN
# 4          NaN   NaN       NaN       NaN  ...  NaN   NaN         NaN
#
#   image_url description county state lat long posting_date
# 0       NaN         NaN    NaN    az NaN  NaN          NaN
# 1       NaN         NaN    NaN    ar NaN  NaN          NaN
# 2       NaN         NaN    NaN    fl NaN  NaN          NaN
# 3       NaN         NaN    NaN    ma NaN  NaN          NaN
# 4       NaN         NaN    NaN    nc NaN  NaN          NaN
#
# [5 rows x 26 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# %matplotlib inline

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/vechiles.txt')

print(df.head())

print(df.info())

print(df.describe())
# Out:
# Empty DataFrame
# Columns: [https://1drv.ms/x/c/b0a9a01fbbeb2e2c/EV8PwAJItsJIpf0ZPDVP9K0BfmoxFwuNfTRBX-OKysI_IA]
# Index: []
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Data columns (total 1 columns):
#  #   Column                                                                               Non-Null Count  Dtype
# ---  ------                                                                               --------------  -----
#  0   https://1drv.ms/x/c/b0a9a01fbbeb2e2c/EV8PwAJItsJIpf0ZPDVP9K0BfmoxFwuNfTRBX-OKysI_IA  0 non-null      object
# dtypes: object(1)
# memory usage: 124.0+ bytes
# None
#        https://1drv.ms/x/c/b0a9a01fbbeb2e2c/EV8PwAJItsJIpf0ZPDVP9K0BfmoxFwuNfTRBX-OKysI_IA
# count                                                   0
# unique                                                  0
# top                                                   NaN
# freq                                                  NaN

# %%
missing_data = df.isnull().sum()
print(missing_data)


missing_percent = (missing_data / len(df)) * 100
print(missing_percent)
# Out:
# https://1drv.ms/x/c/b0a9a01fbbeb2e2c/EV8PwAJItsJIpf0ZPDVP9K0BfmoxFwuNfTRBX-OKysI_IA    0
# dtype: int64
# https://1drv.ms/x/c/b0a9a01fbbeb2e2c/EV8PwAJItsJIpf0ZPDVP9K0BfmoxFwuNfTRBX-OKysI_IA   NaN
# dtype: float64

# %%
duplicates = df.duplicated().sum()
print(f"Number of duplicated rows: {duplicates}")
# Out:
# Number of duplicated rows: 0

# %%
print(df[df['price'] <= 0])

print(df[(df['year'] < 1900) | (df['year'] > 2024)])
# Out:
#                 id                                                url  \
# 10      7218893038  https://elpaso.craigslist.org/ctd/d/el-paso-20...
# 11      7218325704  https://elpaso.craigslist.org/ctd/d/el-paso-20...
# 12      7217788283  https://elpaso.craigslist.org/ctd/d/el-paso-20...
# 13      7217147606  https://elpaso.craigslist.org/ctd/d/el-paso-20...
# 14      7209027818  https://elpaso.craigslist.org/ctd/d/el-paso-20...
# ...            ...                                                ...
# 426764  7303347225  https://wyoming.craigslist.org/ctd/d/casper-pe...
# 426812  7302877815  https://wyoming.craigslist.org/ctd/d/frederick...
# 426832  7302353283  https://wyoming.craigslist.org/ctd/d/frederick...
# 426836  7302301268  https://wyoming.craigslist.org/ctd/d/dassel-20...
# 426868  7301843288  https://wyoming.craigslist.org/ctd/d/frederick...
#
#          region                      region_url  price    year manufacturer  \
# 10      el paso   https://elpaso.craigslist.org      0     NaN          NaN
# 11      el paso   https://elpaso.craigslist.org      0     NaN          NaN
# 12      el paso   https://elpaso.craigslist.org      0     NaN          NaN
# 13      el paso   https://elpaso.craigslist.org      0     NaN          NaN
# 14      el paso   https://elpaso.craigslist.org      0     NaN          NaN
# ...         ...                             ...    ...     ...          ...
# 426764  wyoming  https://wyoming.craigslist.org      0  2018.0          NaN
# 426812  wyoming  https://wyoming.craigslist.org      0  2006.0       toyota
# 426832  wyoming  https://wyoming.craigslist.org      0  2004.0       toyota
# 426836  wyoming  https://wyoming.craigslist.org      0  2018.0          ram
# 426868  wyoming  https://wyoming.craigslist.org      0  2010.0       toyota
#
#                 model  condition    cylinders  ...       size   type  \
# 10                NaN        NaN          NaN  ...        NaN    NaN
# 11                NaN        NaN          NaN  ...        NaN    NaN
# 12                NaN        NaN          NaN  ...        NaN    NaN
# 13                NaN        NaN          NaN  ...        NaN    NaN
# 14                NaN        NaN          NaN  ...        NaN    NaN
# ...               ...        ...          ...  ...        ...    ...
# 426764  peterbilt 579        NaN          NaN  ...        NaN    NaN
# 426812       scion tc  excellent  4 cylinders  ...        NaN    NaN
# 426832          prius  excellent  4 cylinders  ...        NaN    NaN
# 426836           2500  excellent  6 cylinders  ...  full-size  truck
# 426868          venza  excellent  6 cylinders  ...        NaN    NaN
#
#        paint_color                                          image_url  \
# 10             NaN                                                NaN
# 11             NaN                                                NaN
# 12             NaN                                                NaN
# 13             NaN                                                NaN
# 14             NaN                                                NaN
# ...            ...                                                ...
# 426764         NaN  https://images.craigslist.org/00F0F_kfjCcZyncy...
# 426812      silver  https://images.craigslist.org/00B0B_dqmLwdZw8Q...
# 426832        blue  https://images.craigslist.org/00V0V_7Ap4arGS9S...
# 426836       white  https://images.craigslist.org/00i0i_3cSpgdy0qQ...
# 426868        blue  https://images.craigslist.org/00808_hNEilrIb0i...
#
#                                               description county state  \
# 10                                                    NaN    NaN    tx
# 11                                                    NaN    NaN    tx
# 12                                                    NaN    NaN    tx
# 13                                                    NaN    NaN    tx
# 14                                                    NaN    NaN    tx
# ...                                                   ...    ...   ...
# 426764  ◄ PRICES STARTING AT $57,500 ($57,500 and up, ...    NaN    wy
# 426812  2006 *** TOYOTA SCION TC  ***    Call or Text ...    NaN    wy
# 426832  2004 *** TOYOTA PRIUS  ***    Call or Text "To...    NaN    wy
# 426836  Phone: 320-275-2150   2018 RAM 2500 Tradesman ...    NaN    wy
# 426868  2010 *** TOYOTA VENZA AWD V6  ***    Call or T...    NaN    wy
#
#               lat        long              posting_date
# 10            NaN         NaN                       NaN
# 11            NaN         NaN                       NaN
# 12            NaN         NaN                       NaN
# 13            NaN         NaN                       NaN
# 14            NaN         NaN                       NaN
# ...           ...         ...                       ...
# 426764  42.862274 -106.307144  2021-04-07T15:15:05-0600
# 426812  40.114685 -104.971971  2021-04-06T17:00:19-0600
# 426832  40.114685 -104.971971  2021-04-05T17:00:55-0600
# 426836  45.082436  -94.334686  2021-04-05T15:18:42-0600
# 426868  40.114685 -104.971971  2021-04-04T17:00:48-0600
#
# [32895 rows x 26 columns]
# Empty DataFrame
# Columns: [id, url, region, region_url, price, year, manufacturer, model, condition, cylinders, fuel, odometer, title_status, transmission, VIN, drive, size, type, paint_color, image_url, description, county, state, lat, long, posting_date]
# Index: []
#
# [0 rows x 26 columns]

# %%
df.dropna(subset=['price', 'year', 'manufacturer', 'condition'], inplace=True)

df.drop_duplicates(inplace=True)

df = df[df['price'] > 1000]

df = df[(df['year'] > 1900) & (df['year'] <= 2024)]

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 226462 entries, 27 to 426879
# Data columns (total 26 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            226462 non-null  int64
#  1   url           226462 non-null  object
#  2   region        226462 non-null  object
#  3   region_url    226462 non-null  object
#  4   price         226462 non-null  int64
#  5   year          226462 non-null  float64
#  6   manufacturer  226462 non-null  object
#  7   model         224401 non-null  object
#  8   condition     226462 non-null  object
#  9   cylinders     162870 non-null  object
#  10  fuel          226446 non-null  object
#  11  odometer      225088 non-null  float64
#  12  title_status  222183 non-null  object
#  13  transmission  226439 non-null  object
#  14  VIN           137307 non-null  object
#  15  drive         172357 non-null  object
#  16  size          84994 non-null   object
#  17  type          198338 non-null  object
#  18  paint_color   181028 non-null  object
#  19  image_url     226462 non-null  object
#  20  description   226462 non-null  object
#  21  county        0 non-null       float64
#  22  state         226462 non-null  object
#  23  lat           225594 non-null  float64
#  24  long          225594 non-null  float64
#  25  posting_date  226462 non-null  object
# dtypes: float64(5), int64(2), object(19)
# memory usage: 46.6+ MB
# None

# %%
df['car_age'] = 2024 - df['year']

def price_category(price):
    if price < 5000:
        return 'Low'
    elif price < 20000:
        return 'Medium'
    else:
        return 'High'

df['price_category'] = df['price'].apply(price_category)

# %% [markdown]
# #EDA

# %%
top_manufacturers = df['manufacturer'].value_counts().head(10)
top_manufacturers.plot(kind='bar', title='Top 10 Manufacturers', color='skyblue')
plt.xlabel('Manufacturer')
plt.ylabel('Number of Listings')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['price'], bins=50, kde=True, color='green')
plt.title('Price Distribution')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.xlim(0, 100000)
plt.show()

# %%
avg_price_condition = df.groupby('condition')['price'].mean().sort_values()
avg_price_condition.plot(kind='bar', title='Average Price by Condition', color='orange')
plt.xlabel('Condition')
plt.ylabel('Average Price')
plt.show()

# %%
sns.scatterplot(data=df, x='year', y='price', alpha=0.5)
plt.title('Year vs Price')
plt.xlabel('Year')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.countplot(data=df, x='type', hue='condition', palette='viridis', order=df['type'].value_counts().index[:10])
plt.title('Car Types by Condition')
plt.xlabel('Car Type')
plt.ylabel('Number of Cars')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #Q

# %%
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='year', y='price', alpha=0.3)
plt.title('Year of Manufacture vs Price')
plt.xlabel('Year')
plt.ylabel('Price')
plt.show()

# %%
avg_price_by_state = df.groupby('state')['price'].mean().sort_values(ascending=False).head(10)
avg_price_by_state.plot(kind='bar', title='Top 10 States by Average Price', color='teal')
plt.xlabel('State')
plt.ylabel('Average Price')
plt.show()

# %%
avg_price_by_condition = df.groupby('condition')['price'].mean().sort_values()
print(avg_price_by_condition)
# Out:
# condition
# salvage        5257.110497
# new           30720.801772
# good          31951.176770
# like new      40570.867800
# excellent     58094.326412
# fair         966750.807179
# Name: price, dtype: float64

# %%
avg_price_by_condition.plot(kind='bar', color='purple', figsize=(10, 6))
plt.title('Average Price by Condition')
plt.xlabel('Condition')
plt.ylabel('Average Price')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='odometer', y='price', alpha=0.3, color='green')
plt.title('Odometer Reading vs Price')
plt.xlabel('Odometer (Mileage)')
plt.ylabel('Price')
plt.xlim(0, 300000)
plt.ylim(0, 100000)
plt.show()

# %%
fuel_distribution = df['fuel'].value_counts()

print(fuel_distribution)
# Out:
# fuel
# gas         191993
# other        19560
# diesel       10530
# hybrid        3278
# electric      1085
# Name: count, dtype: int64

# %%
fuel_distribution.plot(kind='bar', color='brown', figsize=(10, 6))
plt.title('Fuel Types Distribution')
plt.xlabel('Fuel Type')
plt.ylabel('Number of Listings')
plt.show()

# %%
top_brands = df['manufacturer'].value_counts().head(10)


print(top_brands)
# Out:
# manufacturer
# ford         35292
# chevrolet    30152
# toyota       19237
# honda        12197
# nissan       10243
# jeep          9660
# gmc           8875
# bmw           8809
# ram           7581
# dodge         6815
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
top_brands.plot(kind='bar', color='skyblue', figsize=(10, 6))
plt.title('Top 10 Car Manufacturers')
plt.xlabel('Manufacturer')
plt.ylabel('Number of Listings')
plt.show()

# %%
condition_distribution = df['condition'].value_counts()

print(condition_distribution)
# Out:
# condition
# good         113028
# excellent     88376
# like new      18472
# fair           5321
# new             903
# salvage         362
# Name: count, dtype: int64

# %%
condition_distribution.plot(kind='pie', autopct='%1.1f%%', figsize=(8, 8))
plt.title('Condition of Cars')
plt.ylabel('')
plt.show()

# %% [markdown]
# #done

# %%
df.to_csv('EDA_vehicles.csv', index=False)

print("Cleaned data saved ")
# Out:
# Cleaned data saved
